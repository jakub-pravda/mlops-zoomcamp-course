# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error

# %%
# MLflow setting
import mlflow

mlflow.set_tracking_uri('http://localhost:5000')
mlflow.set_experiment('nyc-taxi-experiment')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/937530806142134978', creation_time=1716308952433, experiment_id='937530806142134978', last_update_time=1716308952433, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %% [markdown]
# ### Load yellow taxi data
# [NY taxi dataset](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page)

# %%
# Read parquets and do some transformations
def read_data_frame(filename):
    df = pd.read_parquet(filename)
    df['duration'] = (df.tpep_dropoff_datetime - df.tpep_pickup_datetime)
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df['duration'] > 0) & (df['duration'] < 120) & (df['passenger_count'].notna())]

    categorical = ['PULocationID', 'DOLocationID']
    numerical = ['trip_distance']
    
    df[categorical] = df[categorical].astype(str)
    return df

# %%
# Prepare train and valdiation data

df_train = read_data_frame('../data/yellow_tripdata_2024-01.parquet')
df_val = read_data_frame('../data/yellow_tripdata_2024-02.parquet')

len(df_train), len(df_val)
# Out:
# (2820972, 2818415)

# %%
# Just describe dataset
df_train.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    2.820972e+06
# mean     1.474504e+01
# std      1.177543e+01
# min      1.666667e-02
# 50%      1.150000e+01
# 95%      3.796667e+01
# 98%      5.070000e+01
# 99%      5.960000e+01
# max      1.199667e+02
# Name: duration, dtype: float64

# %%
sns.distplot(df_train.duration)
sns.distplot(df_val.duration)
# Out:
# /tmp/nix-shell.9Gh3Nb/ipykernel_32310/1764197534.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train.duration)
# /tmp/nix-shell.9Gh3Nb/ipykernel_32310/1764197534.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_val.duration)
# <Axes: xlabel='duration', ylabel='Density'>

# %%
df_train.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                     object
# DOLocationID                     object
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# duration                        float64
# dtype: object

# %%
# Hyperparam tunning
df_train['PU_DO'] = df_train['PULocationID'] + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + df_val['DOLocationID']

# %%
# *** Train model - Linear regression ***

categorical = ['PU_DO'] #['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

# Feature matrix for my model training
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

# Feature matrix for my model training
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# Training part
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

# Prediction part
y_predict = lr.predict(X_val)

# Evaluation part
mean_squared_error(y_val, y_predict, squared=False)
# Out:
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 6.928124492990459

# %%
# Save the model - we'll use this model for entire course
import pickle

with open('../models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

mlflow.log_artifact(local_path='../models/lin_reg.bin', artifact_path='models_pickle|')

# %%
# Plot is somehow weird, maybe we need to do more data cleaning?
sns.distplot(y_predict, label='prediction')
sns.distplot(y_train, label='actual')
plt.legend()
# Out:
# /tmp/nix-shell.9Gh3Nb/ipykernel_32310/7925631.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_predict, label='prediction')
# /tmp/nix-shell.9Gh3Nb/ipykernel_32310/7925631.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %% [markdown]
# ## Try to use Laso reggresion

# %%
from sklearn.linear_model import Lasso

# %%
with mlflow.start_run():

    mlflow.set_tag('developer', 'jacob')

    mlflow.log_param('train-data-path', '../data/yellow_tripdata_2024-01.parquet')
    mlflow.log_param('valid-data-path', '../data/yellow_tripdata_2024-02.parquet')
    
    # *** Train model - Lasso regression ***

    alpha = 0.1
    mlflow.log_param('alpha', alpha)
    
    categorical = ['PU_DO'] #['PULocationID', 'DOLocationID']
    numerical = ['trip_distance']
    
    dv = DictVectorizer()
    
    # Feature matrix for my model training
    train_dicts = df_train[categorical + numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)
    
    # Feature matrix for my model training
    val_dicts = df_val[categorical + numerical].to_dict(orient='records')
    X_val = dv.transform(val_dicts)
    
    # Training part
    target = 'duration'
    y_train = df_train[target].values
    y_val = df_val[target].values
    
    lr_lasso = Lasso(alpha)
    lr_lasso.fit(X_train, y_train)
    
    # Prediction part
    y_predict = lr_lasso.predict(X_val)
    
    # Evaluation part
    rmse = mean_squared_error(y_val, y_predict, squared=False)
    mlflow.log_metric('rmse', rmse)
# Out:
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[29], line 41
#      38 rmse = mean_squared_error(y_val, y_predict, squared=False)
#      39 mlflow.log_metric('rmse', rmse)
# ---> 41 mlflow.log_artifact(local_path='../models/lin_reg.bin', artifact_path='models_pickle/')
#
# File /nix/store/p7269ayxkifgd2himw7j8b17swrwyaaj-python3.11-mlflow-2.12.2/lib/python3.11/site-packages/mlflow/tracking/fluent.py:1068, in log_artifact(local_path, artifact_path, run_id)
#    1040 """
#    1041 Log a local file or directory as an artifact of the currently active run. If no run is
#    1042 active, this method will create a new active run.
#    (...)
#    1065             mlflow.log_artifact(path)
#    1066 """
#    1067 run_id = run_id or _get_or_start_run().info.run_id
# -> 1068 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File /nix/store/p7269ayxkifgd2himw7j8b17swrwyaaj-python3.11-mlflow-2.12.2/lib/python3.11/site-packages/mlflow/tracking/client.py:1215, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1172 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#    1173     """Write a local file or directory to the remote ``artifact_uri``.
#    1174
#    1175     Args:
#    (...)
#    1213
#    1214     """
# -> 1215     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File /nix/store/p7269ayxkifgd2himw7j8b17swrwyaaj-python3.11-mlflow-2.12.2/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:557, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     555     artifact_repo.log_artifacts(local_path, path_name)
#     556 else:
# --> 557     artifact_repo.log_artifact(local_path, artifact_path)
#
# File /nix/store/p7269ayxkifgd2himw7j8b17swrwyaaj-python3.11-mlflow-2.12.2/lib/python3.11/site-packages/mlflow/store/artifact/http_artifact_repo.py:43, in HttpArtifactRepository.log_artifact(self, local_file, artifact_path)
#      42 def log_artifact(self, local_file, artifact_path=None):
# ---> 43     verify_artifact_path(artifact_path)
#      45     # Try to perform multipart upload if the file is large.
#      46     # If the server does not support, or if the upload failed, revert to normal upload.
#      47     if (
#      48         MLFLOW_ENABLE_PROXY_MULTIPART_UPLOAD.get()
#      49         and os.path.getsize(local_file) >= MLFLOW_MULTIPART_UPLOAD_MINIMUM_FILE_SIZE.get()
#      50     ):
#
# File /nix/store/p7269ayxkifgd2himw7j8b17swrwyaaj-python3.11-mlflow-2.12.2/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repo.py:379, in verify_artifact_path(artifact_path)
#     377 def verify_artifact_path(artifact_path):
#     378     if artifact_path and path_not_unique(artifact_path):
# --> 379         raise MlflowException(
#     380             f"Invalid artifact path: '{artifact_path}'. {bad_path_message(artifact_path)}"
#     381         )
#
# MlflowException: Invalid artifact path: 'models_pickle/'. Names may be treated as files in certain cases, and must not resolve to other names when treated as such. This name would resolve to 'models_pickle'

# %% [markdown]
# # MLflow experiment with xgboost
#
# Week 2 of MLOps zoomcamp experiment

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric('rmse', rmse)
        return { 'loss': rmse, 'status': STATUS_OK }

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_slpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials())
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:36:08] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.49067
# [1]	validation-rmse:6.58707
# [2]	validation-rmse:6.39896
# [3]	validation-rmse:6.34327
# [4]	validation-rmse:6.32257
# [5]	validation-rmse:6.31404
# [6]	validation-rmse:6.30803
# [7]	validation-rmse:6.30270
# [8]	validation-rmse:6.29873
# [9]	validation-rmse:6.29531
# [10]	validation-rmse:6.29124
# [11]	validation-rmse:6.28573
# [12]	validation-rmse:6.28181
# [13]	validation-rmse:6.27876
# [14]	validation-rmse:6.27565
# [15]	validation-rmse:6.26784
# [16]	validation-rmse:6.26453
# [17]	validation-rmse:6.26150
# [18]	validation-rmse:6.25858
# [19]	validation-rmse:6.25508
# [20]	validation-rmse:6.25119
# [21]	validation-rmse:6.24895
# [22]	validation-rmse:6.24570
# [23]	validation-rmse:6.24264
# [24]	validation-rmse:6.23963
# [25]	validation-rmse:6.23597
# [26]	validation-rmse:6.23319
# [27]	validation-rmse:6.22584
# [28]	validation-rmse:6.22311
# [29]	validation-rmse:6.22078
# [30]	validation-rmse:6.21856
# [31]	validation-rmse:6.21611
# [32]	validation-rmse:6.21276
# [33]	validation-rmse:6.20960
# [34]	validation-rmse:6.20735
# [35]	validation-rmse:6.20476
# [36]	validation-rmse:6.20345
# [37]	validation-rmse:6.20116
# [38]	validation-rmse:6.19877
# [39]	validation-rmse:6.19702
# [40]	validation-rmse:6.19279
# [41]	validation-rmse:6.19043
# [42]	validation-rmse:6.18872
# [43]	validation-rmse:6.18699
# [44]	validation-rmse:6.18478
# [45]	validation-rmse:6.18124
# [46]	validation-rmse:6.17924
# [47]	validation-rmse:6.17724
# [48]	validation-rmse:6.17537
# [49]	validation-rmse:6.17286
# [50]	validation-rmse:6.16984
# [51]	validation-rmse:6.16783
# [52]	validation-rmse:6.16524
# [53]	validation-rmse:6.16296
# [54]	validation-rmse:6.16148
# [55]	validation-rmse:6.15908
# [56]	validation-rmse:6.15737
# [57]	validation-rmse:6.15563
# [58]	validation-rmse:6.15396
# [59]	validation-rmse:6.15254
# [60]	validation-rmse:6.15061
# [61]	validation-rmse:6.14904
# [62]	validation-rmse:6.14747
# [63]	validation-rmse:6.14546
# [64]	validation-rmse:6.14446
# [65]	validation-rmse:6.14259
# [66]	validation-rmse:6.14129
# [67]	validation-rmse:6.13988
# [68]	validation-rmse:6.13831
# [69]	validation-rmse:6.13647
# [70]	validation-rmse:6.13506
# [71]	validation-rmse:6.13287
# [72]	validation-rmse:6.13170
# [73]	validation-rmse:6.13003
# [74]	validation-rmse:6.12853
# [75]	validation-rmse:6.12735
# [76]	validation-rmse:6.12535
# [77]	validation-rmse:6.12400
# [78]	validation-rmse:6.12229
# [79]	validation-rmse:6.12100
# [80]	validation-rmse:6.11945
# [81]	validation-rmse:6.11851
# [82]	validation-rmse:6.11728
# [83]	validation-rmse:6.11612
# [84]	validation-rmse:6.11519
# [85]	validation-rmse:6.11389
# [86]	validation-rmse:6.11254
# [87]	validation-rmse:6.11171
# [88]	validation-rmse:6.11078
# [89]	validation-rmse:6.10951
# [90]	validation-rmse:6.10836
# [91]	validation-rmse:6.10688
# [92]	validation-rmse:6.10633
# [93]	validation-rmse:6.10479
# [94]	validation-rmse:6.10380
# [95]	validation-rmse:6.10270
# [96]	validation-rmse:6.10162
# [97]	validation-rmse:6.10067
# [98]	validation-rmse:6.09979
# [99]	validation-rmse:6.09889
#   2%|▏         | 1/50 [03:58<3:15:01, 238.81s/trial, best loss: 6.098890916775761]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:40:07] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.55874
# [1]	validation-rmse:8.13358
# [2]	validation-rmse:7.38299
# [3]	validation-rmse:6.99661
# [4]	validation-rmse:6.79747
# [5]	validation-rmse:6.68996
# [6]	validation-rmse:6.63087
# [7]	validation-rmse:6.59434
# [8]	validation-rmse:6.57157
# [9]	validation-rmse:6.55537
# [10]	validation-rmse:6.54698
# [11]	validation-rmse:6.53953
# [12]	validation-rmse:6.53766
# [13]	validation-rmse:6.53372
# [14]	validation-rmse:6.52955
# [15]	validation-rmse:6.52620
# [16]	validation-rmse:6.52406
# [17]	validation-rmse:6.52094
# [18]	validation-rmse:6.51893
# [19]	validation-rmse:6.51643
# [20]	validation-rmse:6.51420
# [21]	validation-rmse:6.51205
# [22]	validation-rmse:6.51008
# [23]	validation-rmse:6.50809
# [24]	validation-rmse:6.50587
# [25]	validation-rmse:6.50370
# [26]	validation-rmse:6.49976
# [27]	validation-rmse:6.49788
# [28]	validation-rmse:6.49642
# [29]	validation-rmse:6.49441
# [30]	validation-rmse:6.49276
# [31]	validation-rmse:6.49089
# [32]	validation-rmse:6.48788
# [33]	validation-rmse:6.48629
# [34]	validation-rmse:6.48469
# [35]	validation-rmse:6.48261
# [36]	validation-rmse:6.48075
# [37]	validation-rmse:6.47917
# [38]	validation-rmse:6.47752
# [39]	validation-rmse:6.47619
# [40]	validation-rmse:6.47455
# [41]	validation-rmse:6.47310
# [42]	validation-rmse:6.46983
# [43]	validation-rmse:6.46875
# [44]	validation-rmse:6.46721
# [45]	validation-rmse:6.46568
# [46]	validation-rmse:6.46423
# [47]	validation-rmse:6.46283
# [48]	validation-rmse:6.46131
# [49]	validation-rmse:6.45972
# [50]	validation-rmse:6.45857
# [51]	validation-rmse:6.45589
# [52]	validation-rmse:6.45471
# [53]	validation-rmse:6.45327
# [54]	validation-rmse:6.45177
# [55]	validation-rmse:6.45033
# [56]	validation-rmse:6.44896
# [57]	validation-rmse:6.44749
# [58]	validation-rmse:6.44559
# [59]	validation-rmse:6.44416
# [60]	validation-rmse:6.44308
# [61]	validation-rmse:6.44181
# [62]	validation-rmse:6.44007
# [63]	validation-rmse:6.43900
# [64]	validation-rmse:6.43738
# [65]	validation-rmse:6.43617
# [66]	validation-rmse:6.43495
# [67]	validation-rmse:6.43360
# [68]	validation-rmse:6.43046
# [69]	validation-rmse:6.42943
# [70]	validation-rmse:6.42828
# [71]	validation-rmse:6.42706
# [72]	validation-rmse:6.42516
# [73]	validation-rmse:6.42393
# [74]	validation-rmse:6.42283
# [75]	validation-rmse:6.42148
# [76]	validation-rmse:6.42025
# [77]	validation-rmse:6.41917
# [78]	validation-rmse:6.41794
# [79]	validation-rmse:6.41686
# [80]	validation-rmse:6.41577
# [81]	validation-rmse:6.41480
# [82]	validation-rmse:6.41371
# [83]	validation-rmse:6.41255
# [84]	validation-rmse:6.41153
# [85]	validation-rmse:6.41033
# [86]	validation-rmse:6.40829
# [87]	validation-rmse:6.40736
# [88]	validation-rmse:6.40641
# [89]	validation-rmse:6.40534
# [90]	validation-rmse:6.40416
# [91]	validation-rmse:6.40327
# [92]	validation-rmse:6.40234
# [93]	validation-rmse:6.40114
# [94]	validation-rmse:6.39961
# [95]	validation-rmse:6.39847
# [96]	validation-rmse:6.39752
# [97]	validation-rmse:6.39662
# [98]	validation-rmse:6.39554
# [99]	validation-rmse:6.39446
#   4%|▍         | 2/50 [07:04<2:45:52, 207.34s/trial, best loss: 6.098890916775761]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:43:12] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.20767
# [1]	validation-rmse:10.42286
# [2]	validation-rmse:9.75194
# [3]	validation-rmse:9.18134
# [4]	validation-rmse:8.69828
# [5]	validation-rmse:8.29139
# [6]	validation-rmse:7.94879
# [7]	validation-rmse:7.66274
# [8]	validation-rmse:7.42427
# [9]	validation-rmse:7.22622
# [10]	validation-rmse:7.06187
# [11]	validation-rmse:6.92443
# [12]	validation-rmse:6.81127
# [13]	validation-rmse:6.71723
# [14]	validation-rmse:6.63962
# [15]	validation-rmse:6.57415
# [16]	validation-rmse:6.51924
# [17]	validation-rmse:6.47389
# [18]	validation-rmse:6.43533
# [19]	validation-rmse:6.40263
# [20]	validation-rmse:6.37508
# [21]	validation-rmse:6.35122
# [22]	validation-rmse:6.33137
# [23]	validation-rmse:6.31408
# [24]	validation-rmse:6.29892
# [25]	validation-rmse:6.28587
# [26]	validation-rmse:6.27442
# [27]	validation-rmse:6.26430
# [28]	validation-rmse:6.25570
# [29]	validation-rmse:6.24740
# [30]	validation-rmse:6.23996
# [31]	validation-rmse:6.23353
# [32]	validation-rmse:6.22791
# [33]	validation-rmse:6.22269
# [34]	validation-rmse:6.21789
# [35]	validation-rmse:6.21303
# [36]	validation-rmse:6.20870
# [37]	validation-rmse:6.20488
# [38]	validation-rmse:6.20148
# [39]	validation-rmse:6.19827
# [40]	validation-rmse:6.19573
# [41]	validation-rmse:6.19325
# [42]	validation-rmse:6.19145
# [43]	validation-rmse:6.18969
# [44]	validation-rmse:6.18784
# [45]	validation-rmse:6.18633
# [46]	validation-rmse:6.18468
# [47]	validation-rmse:6.18355
# [48]	validation-rmse:6.18211
# [49]	validation-rmse:6.18127
# [50]	validation-rmse:6.18028
# [51]	validation-rmse:6.17895
# [52]	validation-rmse:6.17817
# [53]	validation-rmse:6.17708
# [54]	validation-rmse:6.17625
# [55]	validation-rmse:6.17560
# [56]	validation-rmse:6.17496
# [57]	validation-rmse:6.17380
# [58]	validation-rmse:6.17319
# [59]	validation-rmse:6.17249
# [60]	validation-rmse:6.17180
# [61]	validation-rmse:6.17072
# [62]	validation-rmse:6.17018
# [63]	validation-rmse:6.16966
# [64]	validation-rmse:6.16896
# [65]	validation-rmse:6.16839
# [66]	validation-rmse:6.16771
# [67]	validation-rmse:6.16705
# [68]	validation-rmse:6.16656
# [69]	validation-rmse:6.16587
# [70]	validation-rmse:6.16536
# [71]	validation-rmse:6.16482
# [72]	validation-rmse:6.16420
# [73]	validation-rmse:6.16372
# [74]	validation-rmse:6.16321
# [75]	validation-rmse:6.16258
# [76]	validation-rmse:6.16203
# [77]	validation-rmse:6.16114
# [78]	validation-rmse:6.16072
# [79]	validation-rmse:6.16005
# [80]	validation-rmse:6.15953
# [81]	validation-rmse:6.15900
# [82]	validation-rmse:6.15855
# [83]	validation-rmse:6.15808
# [84]	validation-rmse:6.15679
# [85]	validation-rmse:6.15602
# [86]	validation-rmse:6.15542
# [87]	validation-rmse:6.15497
# [88]	validation-rmse:6.15436
# [89]	validation-rmse:6.15394
# [90]	validation-rmse:6.15347
# [91]	validation-rmse:6.15293
# [92]	validation-rmse:6.15242
# [93]	validation-rmse:6.15193
# [94]	validation-rmse:6.15143
# [95]	validation-rmse:6.15093
# [96]	validation-rmse:6.15044
# [97]	validation-rmse:6.15003
# [98]	validation-rmse:6.14947
# [99]	validation-rmse:6.14906
#   6%|▌         | 3/50 [11:22<3:00:41, 230.67s/trial, best loss: 6.098890916775761]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:47:30] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.12462
# [1]	validation-rmse:10.28320
# [2]	validation-rmse:9.57744
# [3]	validation-rmse:8.98878
# [4]	validation-rmse:8.50117
# [5]	validation-rmse:8.09674
# [6]	validation-rmse:7.76579
# [7]	validation-rmse:7.49606
# [8]	validation-rmse:7.27521
# [9]	validation-rmse:7.09513
# [10]	validation-rmse:6.95001
# [11]	validation-rmse:6.83171
# [12]	validation-rmse:6.73429
# [13]	validation-rmse:6.65635
# [14]	validation-rmse:6.59092
# [15]	validation-rmse:6.53725
# [16]	validation-rmse:6.49334
# [17]	validation-rmse:6.45693
# [18]	validation-rmse:6.42647
# [19]	validation-rmse:6.40089
# [20]	validation-rmse:6.37949
# [21]	validation-rmse:6.36141
# [22]	validation-rmse:6.34558
# [23]	validation-rmse:6.33193
# [24]	validation-rmse:6.31983
# [25]	validation-rmse:6.30934
# [26]	validation-rmse:6.30038
# [27]	validation-rmse:6.29291
# [28]	validation-rmse:6.28618
# [29]	validation-rmse:6.28004
# [30]	validation-rmse:6.27402
# [31]	validation-rmse:6.26875
# [32]	validation-rmse:6.26367
# [33]	validation-rmse:6.25941
# [34]	validation-rmse:6.25601
# [35]	validation-rmse:6.25271
# [36]	validation-rmse:6.25004
# [37]	validation-rmse:6.24749
# [38]	validation-rmse:6.24501
# [39]	validation-rmse:6.24343
# [40]	validation-rmse:6.24190
# [41]	validation-rmse:6.24070
# [42]	validation-rmse:6.23976
# [43]	validation-rmse:6.23899
# [44]	validation-rmse:6.23754
# [45]	validation-rmse:6.23687
# [46]	validation-rmse:6.23593
# [47]	validation-rmse:6.23516
# [48]	validation-rmse:6.23384
# [49]	validation-rmse:6.23295
# [50]	validation-rmse:6.23186
# [51]	validation-rmse:6.23113
# [52]	validation-rmse:6.23029
# [53]	validation-rmse:6.22949
# [54]	validation-rmse:6.22875
# [55]	validation-rmse:6.22800
# [56]	validation-rmse:6.22729
# [57]	validation-rmse:6.22660
# [58]	validation-rmse:6.22595
# [59]	validation-rmse:6.22514
# [60]	validation-rmse:6.22445
# [61]	validation-rmse:6.22375
# [62]	validation-rmse:6.22315
# [63]	validation-rmse:6.22243
# [64]	validation-rmse:6.22178
# [65]	validation-rmse:6.22109
# [66]	validation-rmse:6.22031
# [67]	validation-rmse:6.21937
# [68]	validation-rmse:6.21875
# [69]	validation-rmse:6.21803
# [70]	validation-rmse:6.21731
# [71]	validation-rmse:6.21678
# [72]	validation-rmse:6.21623
# [73]	validation-rmse:6.21562
# [74]	validation-rmse:6.21497
# [75]	validation-rmse:6.21441
# [76]	validation-rmse:6.21390
# [77]	validation-rmse:6.21332
# [78]	validation-rmse:6.21274
# [79]	validation-rmse:6.21195
# [80]	validation-rmse:6.21145
# [81]	validation-rmse:6.21099
# [82]	validation-rmse:6.21040
# [83]	validation-rmse:6.20971
# [84]	validation-rmse:6.20889
# [85]	validation-rmse:6.20832
# [86]	validation-rmse:6.20766
# [87]	validation-rmse:6.20708
# [88]	validation-rmse:6.20639
# [89]	validation-rmse:6.20587
# [90]	validation-rmse:6.20535
# [91]	validation-rmse:6.20445
# [92]	validation-rmse:6.20296
# [93]	validation-rmse:6.20246
# [94]	validation-rmse:6.20197
# [95]	validation-rmse:6.20145
# [96]	validation-rmse:6.20090
# [97]	validation-rmse:6.20037
# [98]	validation-rmse:6.19977
# [99]	validation-rmse:6.19879
#   8%|▊         | 4/50 [15:10<2:55:52, 229.41s/trial, best loss: 6.098890916775761]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:51:18] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.94848
# [1]	validation-rmse:9.99293
# [2]	validation-rmse:9.22039
# [3]	validation-rmse:8.60163
# [4]	validation-rmse:8.10932
# [5]	validation-rmse:7.72100
# [6]	validation-rmse:7.41592
# [7]	validation-rmse:7.17659
# [8]	validation-rmse:6.99043
# [9]	validation-rmse:6.84492
# [10]	validation-rmse:6.73061
# [11]	validation-rmse:6.64027
# [12]	validation-rmse:6.56956
# [13]	validation-rmse:6.51322
# [14]	validation-rmse:6.46802
# [15]	validation-rmse:6.43105
# [16]	validation-rmse:6.40124
# [17]	validation-rmse:6.37646
# [18]	validation-rmse:6.35637
# [19]	validation-rmse:6.33941
# [20]	validation-rmse:6.32499
# [21]	validation-rmse:6.31241
# [22]	validation-rmse:6.30221
# [23]	validation-rmse:6.29340
# [24]	validation-rmse:6.28622
# [25]	validation-rmse:6.27929
# [26]	validation-rmse:6.27392
# [27]	validation-rmse:6.26867
# [28]	validation-rmse:6.26434
# [29]	validation-rmse:6.25987
# [30]	validation-rmse:6.25601
# [31]	validation-rmse:6.25253
# [32]	validation-rmse:6.24980
# [33]	validation-rmse:6.24705
# [34]	validation-rmse:6.24524
# [35]	validation-rmse:6.24324
# [36]	validation-rmse:6.24129
# [37]	validation-rmse:6.24036
# [38]	validation-rmse:6.23882
# [39]	validation-rmse:6.23791
# [40]	validation-rmse:6.23619
# [41]	validation-rmse:6.23548
# [42]	validation-rmse:6.23478
# [43]	validation-rmse:6.23361
# [44]	validation-rmse:6.23246
# [45]	validation-rmse:6.23173
# [46]	validation-rmse:6.23109
# [47]	validation-rmse:6.23045
# [48]	validation-rmse:6.22964
# [49]	validation-rmse:6.22843
# [50]	validation-rmse:6.22748
# [51]	validation-rmse:6.22686
# [52]	validation-rmse:6.22620
# [53]	validation-rmse:6.22483
# [54]	validation-rmse:6.22394
# [55]	validation-rmse:6.22311
# [56]	validation-rmse:6.22251
# [57]	validation-rmse:6.22188
# [58]	validation-rmse:6.22122
# [59]	validation-rmse:6.22054
# [60]	validation-rmse:6.21980
# [61]	validation-rmse:6.21893
# [62]	validation-rmse:6.21804
# [63]	validation-rmse:6.21744
# [64]	validation-rmse:6.21669
# [65]	validation-rmse:6.21615
# [66]	validation-rmse:6.21566
# [67]	validation-rmse:6.21501
# [68]	validation-rmse:6.21451
# [69]	validation-rmse:6.21387
# [70]	validation-rmse:6.21328
# [71]	validation-rmse:6.21241
# [72]	validation-rmse:6.21189
# [73]	validation-rmse:6.21131
# [74]	validation-rmse:6.21079
# [75]	validation-rmse:6.21029
# [76]	validation-rmse:6.20961
# [77]	validation-rmse:6.20863
# [78]	validation-rmse:6.20734
# [79]	validation-rmse:6.20627
# [80]	validation-rmse:6.20540
# [81]	validation-rmse:6.20501
# [82]	validation-rmse:6.20456
# [83]	validation-rmse:6.20404
# [84]	validation-rmse:6.20344
# [85]	validation-rmse:6.20303
# [86]	validation-rmse:6.20257
# [87]	validation-rmse:6.20204
# [88]	validation-rmse:6.20143
# [89]	validation-rmse:6.20065
# [90]	validation-rmse:6.19988
# [91]	validation-rmse:6.19946
# [92]	validation-rmse:6.19908
# [93]	validation-rmse:6.19854
# [94]	validation-rmse:6.19808
# [95]	validation-rmse:6.19759
# [96]	validation-rmse:6.19671
# [97]	validation-rmse:6.19578
# [98]	validation-rmse:6.19503
# [99]	validation-rmse:6.19450
#  10%|█         | 5/50 [18:57<2:51:34, 228.76s/trial, best loss: 6.098890916775761]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [21:55:05] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.90094
# [1]	validation-rmse:9.91374
# [2]	validation-rmse:9.12122
# [3]	validation-rmse:8.48808
# [4]	validation-rmse:7.99246
# [5]	validation-rmse:7.60393
# [6]	validation-rmse:7.30063
# [7]	validation-rmse:7.06408
# [8]	validation-rmse:6.88315
# [9]	validation-rmse:6.73997
# [10]	validation-rmse:6.63271
# [11]	validation-rmse:6.54424
# [12]	validation-rmse:6.47797
# [13]	validation-rmse:6.42221
# [14]	validation-rmse:6.37975
# [15]	validation-rmse:6.34575
# [16]	validation-rmse:6.31821
# [17]	validation-rmse:6.29525
# [18]	validation-rmse:6.27668
# [19]	validation-rmse:6.26117
# [20]	validation-rmse:6.24765
# [21]	validation-rmse:6.23685
# [22]	validation-rmse:6.22719
# [23]	validation-rmse:6.21926
# [24]	validation-rmse:6.21163
# [25]	validation-rmse:6.20477
# [26]	validation-rmse:6.19914
# [27]	validation-rmse:6.19377
# [28]	validation-rmse:6.18976
# [29]	validation-rmse:6.18660
# [30]	validation-rmse:6.18362
# [31]	validation-rmse:6.17990
# [32]	validation-rmse:6.17602
# [33]	validation-rmse:6.17431
# [34]	validation-rmse:6.17218
# [35]	validation-rmse:6.17045
# [36]	validation-rmse:6.16942
# [37]	validation-rmse:6.16774
# [38]	validation-rmse:6.16669
# [39]	validation-rmse:6.16560
# [40]	validation-rmse:6.16409
# [41]	validation-rmse:6.16308
# [42]	validation-rmse:6.16225
# [43]	validation-rmse:6.16137
# [44]	validation-rmse:6.16028
# [45]	validation-rmse:6.15957
# [46]	validation-rmse:6.15871
# [47]	validation-rmse:6.15765
# [48]	validation-rmse:6.15684
# [49]	validation-rmse:6.15607
# [50]	validation-rmse:6.15527
# [51]	validation-rmse:6.15472
# [52]	validation-rmse:6.15398
# [53]	validation-rmse:6.15317
# [54]	validation-rmse:6.15239
# [55]	validation-rmse:6.15172
# [56]	validation-rmse:6.15102
# [57]	validation-rmse:6.15026
# [58]	validation-rmse:6.14943
# [59]	validation-rmse:6.14874
# [60]	validation-rmse:6.14796
# [61]	validation-rmse:6.14719
# [62]	validation-rmse:6.14649
# [63]	validation-rmse:6.14585
# [64]	validation-rmse:6.14512
# ...
# [17]	validation-rmse:6.09810
# [18]	validation-rmse:6.09539
# [19]	validation-rmse:6.09256
# [20]	validation-rmse:6.09016
# [21]	validation-rmse:6.08520
# [22]	validation-rmse:6.08245
# [23]	validation-rmse:6.08043
# [24]	validation-rmse:6.07426
# [25]	validation-rmse:6.07165
# [26]	validation-rmse:6.06901
# [27]	validation-rmse:6.06678
# [28]	validation-rmse:6.06413
# [29]	validation-rmse:6.05835
# [30]	validation-rmse:6.05581
# [31]	validation-rmse:6.05352
# [32]	validation-rmse:6.04616
# [33]	validation-rmse:6.03944
# [34]	validation-rmse:6.03633
# [35]	validation-rmse:6.03366
# [36]	validation-rmse:6.03169
# [37]	validation-rmse:6.02888
# [38]	validation-rmse:6.02795
# [39]	validation-rmse:6.02694
# [40]	validation-rmse:6.02480
# [41]	validation-rmse:6.02271
# [42]	validation-rmse:6.02153
# [43]	validation-rmse:6.02045
# [44]	validation-rmse:6.01909
# [45]	validation-rmse:6.01905
# [46]	validation-rmse:6.01703
# [47]	validation-rmse:6.01629
# [48]	validation-rmse:6.01512
# [49]	validation-rmse:6.01425
# [50]	validation-rmse:6.01172
# [51]	validation-rmse:6.01156
# [52]	validation-rmse:6.00901
# [53]	validation-rmse:6.00872
# [54]	validation-rmse:6.00791
# [55]	validation-rmse:6.00670
# [56]	validation-rmse:6.00573
# [57]	validation-rmse:6.00560
# [58]	validation-rmse:6.00507
# [59]	validation-rmse:6.00446
# [60]	validation-rmse:6.00317
# [61]	validation-rmse:6.00229
# [62]	validation-rmse:6.00179
# [63]	validation-rmse:6.00108
# [64]	validation-rmse:6.00082
# [65]	validation-rmse:6.00061
# [66]	validation-rmse:6.00044
# [67]	validation-rmse:6.00003
# [68]	validation-rmse:5.99954
# [69]	validation-rmse:5.99926
# [70]	validation-rmse:5.99894
# [71]	validation-rmse:5.99869
# [72]	validation-rmse:5.99756
# [73]	validation-rmse:5.99683
# [74]	validation-rmse:5.99643
# [75]	validation-rmse:5.99613
# [76]	validation-rmse:5.99572
# [77]	validation-rmse:5.99542
# [78]	validation-rmse:5.99492
# [79]	validation-rmse:5.99476
# [80]	validation-rmse:5.99465
# [81]	validation-rmse:5.99427
# [82]	validation-rmse:5.99423
# [83]	validation-rmse:5.99434
# [84]	validation-rmse:5.99436
# [85]	validation-rmse:5.99423
# [86]	validation-rmse:5.99407
# [87]	validation-rmse:5.99396
# [88]	validation-rmse:5.99356
# [89]	validation-rmse:5.99327
# [90]	validation-rmse:5.99293
# [91]	validation-rmse:5.99216
# [92]	validation-rmse:5.99221
# [93]	validation-rmse:5.99231
# [94]	validation-rmse:5.99216
# [95]	validation-rmse:5.99217
# [96]	validation-rmse:5.99208
# [97]	validation-rmse:5.99219
# [98]	validation-rmse:5.99183
# [99]	validation-rmse:5.99148
#  44%|████▍     | 22/50 [11:21:55<30:10:56, 3880.58s/trial, best loss: 5.985863451148275]
# /nix/store/kvpg58s66ywi60yw53h79zvfhlcbpnc0-python3.11-scikit-learn-1.4.2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [08:58:03] WARNING: /build/source/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:6.41155
# [1]	validation-rmse:6.19961
# [2]	validation-rmse:6.17039
# [3]	validation-rmse:6.16058
# [4]	validation-rmse:6.15299
# [5]	validation-rmse:6.14571
# [6]	validation-rmse:6.14015
#  44%|████▍     | 22/50 [11:23:08<14:29:27, 1863.13s/trial, best loss: 5.985863451148275]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials())
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File /nix/store/gkxhhjwfglbf155kvzwypy11m5pl132v-python3.11-hyperopt-0.2.7/lib/python3.11/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[34], line 5, in objective(params)
#       3 mlflow.set_tag('model', 'xgboost')
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=100,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /nix/store/zmjah4xc5hp41c41cbrbk1ac7b922pjx-python3.11-xgboost-2.0.3/lib/python3.11/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
